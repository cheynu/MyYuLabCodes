# %%
import os
import deeplabcut

# %%
# config_folder = 'C:\\Users\\jiani\\OneDrive\\00_Work\\02_Code\\DLCModels\\DLCModel-CJM-\\Levi'

# working_path  = 'E:\\OneDrive\\00_Work\\03_Projects\\11_DLCTracking\\DLCTrackingModels\\Iota\\Model'
# choose this if using the laptop

working_path  = 'C:\\Users\\jiani\\OneDrive\\00_Work\\03_Projects\\11_DLCTracking\\DLCTrackingModels\\Iota\\Model'
print(working_path)
path_config_file = os.path.join(working_path, 'IotaBox7-WXN-2022-12-07', 'config.yaml')
print(path_config_file)

vid_folder_main = 'C:\\Users\\jiani\\OneDrive\\00_Work\\03_Projects\\06_TimingBehavior\\VideoAnalysis\\ANMs\\Iota\\01_Kornblum100ms\\20221111\\VideoClips'
vid_types = ['CuedRelease', 'UncuedRelease']
shuffle = 1

for type in vid_types:
    vid_folder_sub = os.path.join(vid_folder_main, type)
    print(vid_folder_sub)
    for vtype in ['.avi']:
        print(vtype)
        deeplabcut.analyze_videos(path_config_file, [vid_folder_sub], shuffle=shuffle, videotype=vtype, save_as_csv = True)
# Out:
# C:\Users\jiani\OneDrive\00_Work\03_Projects\11_DLCTracking\DLCTrackingModels\Iota\Model
# C:\Users\jiani\OneDrive\00_Work\03_Projects\11_DLCTracking\DLCTrackingModels\Iota\Model\IotaBox7-WXN-2022-12-07\config.yaml
# C:\Users\jiani\OneDrive\00_Work\03_Projects\06_TimingBehavior\VideoAnalysis\ANMs\Iota\01_Kornblum100ms\20221111\VideoClips\CuedRelease
# .avi
# Using snapshot-723000 for model C:\Users\jiani\OneDrive\00_Work\03_Projects\11_DLCTracking\DLCTrackingModels\Iota\Model\IotaBox7-WXN-2022-12-07\dlc-models\iteration-0\IotaBox7Dec7-trainset95shuffle1
# C:\Users\jiani\anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...
